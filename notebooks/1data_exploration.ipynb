# %%
import pandas as pd

# %%
data = pd.read_csv('../data/raw/viewingActivity_raw.csv')
data.head()
# Out:
#    Duration           Start Time Profile Name     Country  Bookmark  \
# 0  00:06:21  2025-12-28 09:19:43        Hasss  IN (India)  00:06:32
# 1  00:00:03  2025-12-28 09:18:56        Hasss  IN (India)  00:05:05
# 2  00:00:14  2025-12-28 07:08:23        Hasss  IN (India)  00:00:14
# 3  00:04:14  2025-12-28 06:32:27        Hasss  IN (India)  02:20:14
# 4  00:21:40  2025-12-28 05:35:33        Hasss  IN (India)  00:41:52
#
#    Latest Bookmark Supplemental Video Type                       Attributes  \
# 0         00:06:32                     NaN                              NaN
# 1         00:05:05                     NaN                              NaN
# 2         00:00:14                    HOOK  Autoplayed: user action: None;
# 3         02:20:14                     NaN                              NaN
# 4  Not latest view                     NaN                              NaN
#
#                             Device Type  \
# 0  Apple iPad Pro 11 4th Gen Wi-Fi iPad
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5888 entries, 0 to 5887
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Duration                 5888 non-null   object
#  1   Start Time               5888 non-null   object
#  2   Profile Name             5888 non-null   object
#  3   Country                  5888 non-null   object
#  4   Bookmark                 5888 non-null   object
#  5   Latest Bookmark          5888 non-null   object
#  6   Supplemental Video Type  76 non-null     object
#  7   Attributes               404 non-null    object
#  8   Device Type              5888 non-null   object
#  9   Title                    5888 non-null   object
# dtypes: object(10)
# memory usage: 460.1+ KB

# %%
data.describe()
# Out:
#         Duration           Start Time Profile Name     Country  Bookmark  \
# count       5888                 5888         5888        5888      5888
# unique      1759                 5884            4           6      2554
# top     00:00:01  2025-12-19 01:26:46        Hasss  IN (India)  00:00:02
# freq         186                    2         3513        4245        65
#
#         Latest Bookmark Supplemental Video Type  \
# count              5888                      76
# unique             1350                       4
# top     Not latest view                    HOOK
# freq               3855                      55
#
#                              Attributes      Device Type  \
# count                               404             5888
# unique                                2               14
# top     Autoplayed: user action: None;   Apple iPhone 11
# freq                                232             1509
#
#                                              Title
# ...

# %%
data['Profile Name'].unique()
# Out:
# array(['Hasss', 'Kids', 'Mani', 'Adna kuthuna'], dtype=object)

# %%
data
# Out:
#       Duration           Start Time Profile Name              Country  \
# 0     00:06:21  2025-12-28 09:19:43        Hasss           IN (India)
# 1     00:00:03  2025-12-28 09:18:56        Hasss           IN (India)
# 2     00:00:14  2025-12-28 07:08:23        Hasss           IN (India)
# 3     00:04:14  2025-12-28 06:32:27        Hasss           IN (India)
# 4     00:21:40  2025-12-28 05:35:33        Hasss           IN (India)
# ...        ...                  ...          ...                  ...
# 5883  00:29:23  2022-08-13 12:07:23        Hasss           IN (India)
# 5884  00:20:45  2022-08-13 11:56:11         Mani  GB (United Kingdom)
# 5885  00:27:32  2022-08-13 11:38:26        Hasss           IN (India)
# 5886  00:27:40  2022-08-13 11:10:18        Hasss           IN (India)
# 5887  00:02:31  2022-08-13 11:05:41         Mani  GB (United Kingdom)
#
#       Bookmark  Latest Bookmark Supplemental Video Type  \
# 0     00:06:32         00:06:32                     NaN
# ...

# %% [markdown]
# Important Columns
# - Duration
# - Start TIme
# - Title
# - Profile Name (to filter out particular profile)
#
# Columns to drop
# - Country
# - Bookmark
# - Latest Bookmark
# - Supplemental Video Type
# - Attributes
# - Device Type
#
# Obesrvations
# - Trailer and Primary Hook viewing history is also included as separate rows
# - Title includes Season and Episode Number
# - Duration is in the format hour:minute:second
